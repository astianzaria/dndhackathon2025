# %%
from IPython.display import Image

# %% [markdown]
# measuring the impact and improvement and sentiment for citizen and projection for the impact of the exposure (patronage and perception of public transport)
# know your user, do user research! understand user pain points- to know what.
# we propose 2 approach!
# 1) customer survey (annually)
#
#         1) for customer satisfaction! score is x/100-- wide range of bus stop features~
#         2) user behaviour; journey characteristics

# %%
Image(filename="images/user_survey.png")
#this survey reference is from Tfl (Transport for London)

# %% [markdown]
# 2) scrapping from SMP (social media platform) using Sentiment Analysis with VADER or BERT to automate user feedback(s) or perception towards public transportation
# based on this journal, we could use this approach to gather public perception from social media such as X (Twitter)
#
# Vader --> predefined cant detect sarcasm but easier - simpler
# BERT --> more dynamic

# %%
Image(filename="images/journal_name.png")

# %% [markdown]
# a social media data-driven framework that would allow real-time monitoring of transportation trends by agencies, researchers, and professionals. A better understanding of the demands and viewpoints of users may help with public transportation planning, management, and supervision, as well as achieving transportation policy objectives
